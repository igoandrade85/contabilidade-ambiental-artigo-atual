# %% [markdown]
# # Listagem de revistas e periódicos de contabilidade

# %% [markdown]
# **Fonte:** https://anpcont.org.br/periodicos-de-contabilidade/
#
# ![ANPCONT](../img/anpcont-home.png)

# %% [markdown]
# **Bibliotecas importadas**

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

# %%
matplotlib.rc('text', usetex=True)
matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
plt.style.use('seaborn')
plt.rcParams["font.family"] = "serif"
# Out:
# /tmp/ipykernel_22119/691268837.py:2: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

# %%
url = 'https://anpcont.org.br/periodicos-de-contabilidade/'

# %%
def lista_periodicos_anpcont():
    url = 'https://anpcont.org.br/periodicos-de-contabilidade/'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find('table')
    # Captura cabeçalho da tabela como uma lista
    thead = table.find('thead')
    header = ['Url']
    for th in thead.find_all('th'):
        header.append(th.text)
    tbody = table.find('tbody')
    # Captura os dados da tabela como uma lista de listas
    list_data = []
    for tr in tbody.find_all('tr'):
        row = []
        for td in tr.find_all('td'):
            try:
                a = td.find('a', href=True)
                href = a['href']
                row.append(href)
                row.append(a.text)
            except:
                row.append(td.text)
        list_data.append(row)
    # Converte os dados da tabela em um dataframe pandas
    df = pd.DataFrame(list_data, columns=header)
    return df

# %%
periodicos_df = lista_periodicos_anpcont()
periodicos_df
# Out:
#                                                   Url  \
# 0           http://asaa.anpcont.org.br/index.php/asaa
# 1                        http://www.bbronline.com.br/
# 2   https://revistas.face.ufmg.br/index.php/contab...
# 3                           http://rbgn.fecap.br/RBGN
# 4                              http://rcf.fea.usp.br/
# 5   https://periodicos.ufsc.br/index.php/contabili...
# 6                      http://www.revistas.usp.br/rco
# 7   http://proxy.furb.br/ojs/index.php/universocon...
# 8          http://revistas.unisinos.br/index.php/base
# 9                          http://www.cgg-amg.unb.br/
# 10  http://www.custoseagronegocioonline.com.br/pri...
# 11            http://www.repec.org.br/index.php/repec
# 12  http://www.periodicos.uem.br/ojs/index.php/Enf...
# 13  http://www.atena.org.br/revista/ojs-2.2.3-06/i...
# 14  http://revista.crcsc.org.br/revista/ojs-2.2.3-...
# 15  http://150.165.111.246/revistaadmin/index.php/...
# 16  http://www.atena.org.br/revista/ojs-2.2.3-08/i...
# 17      http://www.revistas.uneb.br/index.php/financ/
# 18             https://revistas.ufrj.br/index.php/scg
# 19                https://periodicos.ufrn.br/ambiente
# 20        http://editora.unoesc.edu.br/index.php/race
# 21  https://www.fundace.org.br/revistaracef/index....
# 22   http://ojs.c3sl.ufpr.br/ojs2/index.php/rcc/index
# 23         http://periodicos.ufpb.br/index.php/recfin
# 24  http://revista.crcmg.org.br/index.php?journal=...
# 25      http://revistas.utfpr.edu.br/pb/index.php/CAP
# 26        http://www.seer.ufrgs.br/index.php/ConTexto
# 27          https://abcustos.emnuvens.com.br/abcustos
# 28  https://portalseer.ufba.br/index.php/rcontabil...
# 29            http://www.ojs.ufpi.br/index.php/gecont
# 30             http://www.seer.furg.br/sinergia/index
# 31  http://editorarevistas.mackenzie.br/index.php/pcg
# 32           http://www.reacfat.com.br/index.php/reac
# 33  http://www.revista.ufpe.br/ricontabeis/index.p...
# 34                              http://rbc.cfc.org.br
#
#                                               Revista  \
# 0   Advances in Scientific and Applied Accounting ...
# 1                     Brazilian Business Review – BBR
# 2                       Contabilidade Vista & Revista
# 3     Revista Brasileira de Gestão de Negócios – RBGN
# 4              Revista Contabilidade & Finanças (USP)
# 5        Revista Contemporânea de Contabilidade – RCC
# 6       Revista de Contabilidade e Organizações – RCO
# 7                           Revista Universo Contábil
# 8                                     BASE (UNISINOS)
# 9           Contabilidade, Gestão e Governança – CGG
# 10                       Custos e @gronegócio on line
# 11  Revista de Educação e Pesquisa em Contabilidad...
# 12                 Revista Enfoque: Reflexão Contábil
# 13                                    Pensar Contábil
# 14            Revista Catarinense da Ciência Contábil
# 15  Revista de Administração, Contabilidade e Sust...
# 16  Revista de Contabilidade do Mestrado em Ciênci...
# 17        Revista de Gestão, Finanças e Contabilidade
# 18                  Sociedade, Contabilidade e Gestão
# 19                          Revista Ambiente Contábil
# 20  Revista de Administração, Contabilidade e Econ...
# 21  Revista de Administração, Contabilidade e Econ...
# 22    Revista de Contabilidade e Controladoria – RC&C
# 23                      Revista Evidenciação Contábil
# 24             Revista Mineira de Contabilidade – RMC
# 25                      CAP Accounting and Management
# 26                                           ConTexto
# 27  Revista da Associação Brasileira de Custos – A...
# 28                   Revista de Contabilidade da UFBA
# 29          Revista de Gestão e Contabilidade da UFPI
# 30  Revista do Instituto de Ciências Econômicas, A...
# 31                 Práticas em Contabilidade e Gestão
# 32    Revista de Administração e Contabilidade da FAT
# 33               Revista de Informação Contábil – RIC
# 34          Revista Brasileira de Contabilidade – RBC
#
#                               Instituição QUALIS
# 0                                 ANPCONT     A2
# 1                               FUCAPE/ES     A2
# 2                                 UFMG/MG     A2
# 3                                FECAP/SP     A2
# 4                                 FEA/USP     A2
# 5                                 UFSC/SC     A2
# 6                              FEA/USP/RP     A2
# 7                                 FURB/SC     A2
# 8                             UNISINOS/RS     B1
# 9                                     UnB     B1
# 10                                  UFRPE     B1
# 11                           Abracicon/DF     B1
# 12                                 UEM/PR     B1
# 13                                 CRC/RJ     B2
# 14                                 CRC/SC     B2
# 15                       UFCG – CCJS/UACC     B2
# 16                                UERJ/RJ     B2
# 17                                   UNEB     B2
# 18                             PPGCC/UFRJ     B2
# 19                                   UFRN     B3
# 20                              UNOESC/SC     B3
# 21                                FUNDACE     B3
# 22                                UFPR/PR     B3
# 23                                   UFPB     B3
# 24                                 CRC-MG     B3
# 25                                  UTFPR     B4
# 26                                  UFRGS     B4
# 27  ABC – Associação Brasileira de Custos     B4
# 28                                   UFBA     B4
# 29                                   UFPI     B4
# 30                                FURG/RS     B4
# 31                              Mackenzie     B5
# 32             Fac. Anisio Teixeira (FAT)     B5
# 33                                UFPE/PE     B5
# 34      Conselho Federal de Contabilidade      C

# %%
periodicos_df.to_csv('../periodicos_anpcont.csv', index=False)

# %%
qualis = periodicos_df['QUALIS'].value_counts()
qualis
# Out:
# A2    8
# B2    6
# B3    6
# B4    6
# B1    5
# B5    3
# C     1
# Name: QUALIS, dtype: int64

# %%
fig, ax = plt.subplots()
ax = qualis.plot.bar(figsize=(10,5), title='Quantidade de Periódicos de Contabilidade por Classificação QUALIS')
ax.set_xlabel('Qualis')
ax.set_ylabel('Quantidade')
plt.show()
